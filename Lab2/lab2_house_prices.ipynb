# %% [markdown]
# # ARTI 308 – Lab 2 (House Prices Dataset)
# ## Part 3: Loading and Inspecting the Dataset in Python
#
# This notebook:
# - Loads the dataset using Pandas
# - Displays the dataset shape
# - Shows the first rows
# - Shows column names and data types

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\balza\\OneDrive\\GitHub\\ARTI308-ML-Lab2'

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# If your CSV is in the same folder as this notebook, this will work:
file_name = "data.csv"

df = pd.read_csv(file_name)

print("✅ Dataset loaded successfully!")

# %%
print("📌 Dataset Shape (rows, columns):", df.shape)

# %%
df.head()

# %%
print("📌 Column Names:")
print(df.columns)

# %%
df.info()

# %%
df.describe(include="all")

# %%
print("📌 Missing values per column:")
df.isna().sum()
